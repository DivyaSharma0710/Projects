# %%
class Pattern():
    def __init__(self,text):
        self.text=text  
    def A(self):
        for i in range(5):
            if i == 2:
                print("*",end=" ")
            else:
                print(" ",end=" ")
        print()
        for i in range(5):
            if i%2!=0:
                print("*",end=" ")
            else:
                print(" ",end=" ")
        print( )
        for i in range(5):
             print("*",end=" ")
        print()
        for i in range(2):
            print("*",end=" ")
            for j in range(3):
                print(" ",end=" ")
            print("*")
    def B(self):
    
        for i in range(0,5):
            if i==0 or i==4:
                for j in range(5):
                    print("*",end=" ")
            if i==2:
                    print("  ",end="")
                    for j in range(4):
                        print("*",end=" ")        
            if i==1 or i==3:
                print()
                print(" ",end=" ")
                print("*",end=" ")
                for j in range(3):
                    print(" ",end=" ")
                print("*")
                
                
    def C(self):
        for j in range(0,5):
            if j==0 or j==4: 
                for i in range(0,4):
                    print(" ",end='')
                    print("*",end='')
                print()
            else:
                print("*")
    
    
    def D(self):
        for i in  range(5):
            print("*",end=" ")
        print()
        for i in range(3):
            print(" ",end=" ")
            print("*",end=" ")
            for j in range(3):
                print(" ",end=" ")
            print("*")
        for i in  range(5):
            print("*",end=" ")
        
    
    def E(self):
        for j in range(0,5):
            if j==0 or j==4 or j==2: 
                for i in range(0,5):
                    print("*",end=' ')
                print()
            else:
                print("*")
    
    
    def F(self):
        for j in range(0,5):
            if j==0  or j==2: 
                for i in range(0,5):
                    print("*",end=' ')
                print()
            else:
                print("*")
    
  
    def G(self):
        for i in range(0,5):
            if i==0 or i==4:
                print(" ",end=' ')
                for j in range(0,3):
                    print("*",end=' ')
                print()
            elif i==2:
                print("*",end=' ')
                print(" ",end=' ')
                for k in range(0,3):
                     print('*',end=' ')
                print()
            elif i==3:
                print("*",end=' ')
                for k in range(0,3):
                    print(' ',end=' ')
                print("*")
            else:
                    print('*')
    
    
    
    def H(self):
        for i in range(2):
            print("*",end=" ")
            for j in range(3):
                print(" ",end=" ")
            print("*")
        for i in range(5):
            print("*",end=" ")
        print()
        for i in range(2):
            print("*",end=" ")
            for j in range(3):
                print(" ",end=" ")
            print("*")
    
    
    def I(self):
        for i in range(5):
            if i==0 or i==4:
                for i in range(5):
                    print("*",end=" ")
                print()
            else:
                print("   ",end=" ")
                print("*")
    
    
    def J(self):
        for i in range(0,5):
            if i == 0:
                for j in range(0,5):
                    print("*",end=' ')
                print()
            elif i ==4:
                for j in range(0,3):
                    print("*",end=' ')
                print()
        
            else:
                for j in range(0,4):
                    if j==3:
                        print("*",end=' ')
                    else:
                        print(" ",end=" ")
                print()
    
    def K(self):
        for i in range(3):
            print("*",end=" ")
            for j in range(2-i):
                print(" ",end=" ")
            print("*")
        for i in range(2):
            print("*",end=" ")
            for j in range(i+1):
                 print(" ",end=" ")
            print("*")
     
    
    def L(self):
        for i in range(0,4):
            print('*')
        for i in range(5):
            print("*",end=' ')
            
    def M(self):
            for i in range(2):
                print("*",end=" ")
                for i in range(3):
                    print(" ",end=' ')
            print()
            for i in range(5):
                if i!=2:
                    print("*",end=' ')
                else:
                    print(" ",end=' ')
            print()
            for i in range(5):
                if i!=1 and i!=3:
                    print("*",end=' ')
                else:
                    print(" ",end=' ')
            print()
            for i in range(2):
                    print("*",end=" ")
                    for j in range(3):
                        print(" ",end=" ")
                    print("*")
    def N(self):
        for i in range(1,6):
                print("*",end=" ")
                for k in range(i-1):
                    print(" ",end="")
                print("*",end=" ")
                for k in range(5-i):
                      print(" ",end="")
                print("*",end="")
                print()
            
    def  O(self):
        for i in range(0,5):
            if i==0 or i==4:
                for j in range(0,5):
                    if j==0 or j==4:
                        print(" ",end=" ")
                    else:
                        print("*",end=" ")
                print()
            else:
                for k in range(0,5):
                    if k==0 or k==4:
                        print("*",end=" ")
                    else:
                        print(" ",end=" ")
                print()
    
    def P(self):
        for i in range(1,4):
            if i == 2:
                print("*",end=" ")
                for j in range(3):
                     print(" ",end=" ")
                print("*")
            else:
                for j in range(4):
                    print("*",end=" ")
                print()
        for i in range(2):
            print("*")

    def Q(self):
        for i in range(0,5):
            if i==0 or i==4:
                print(" ",end=' ')
                for j in range(0,3):
                    print("*",end=' ')
                if i==4:
                    print(" ",end=' ')
                    print("*",end=' ')
                else:
                    print(" ")
        
            elif i==2:
                print("*",end=' ')
                for j in range(0,2):
                    print(" ",end=' ')
                print("*") 
            else:
                print("*",end=' ')
                for j in range(0,3):
                    print(" ",end=' ')
                print("*")
        
    def R(self):
        for i in range(1,4):
            if i == 2:
                print("*",end=" ")
                for j in range(3):
                     print(" ",end=" ")
                print("*")
            else:
                for j in range(4):
                    print("*",end=" ")
                print()
        for i in range(2):
            print('*',end=' ')
            for j in range(2+i):
                print(" ",end=' ')
            print('*')
    
        
    def S(self):
         for i in range(5):
            if i%2==0:
                for j in range(5):
                    print("*",end=" ")
                print()
            elif i==1:
                print("*")
            else:
                for i in range(4):
                    print(" ",end=' ')
                print('*')
    def T(self):
        for i in range(5):
            if i==0 :
                for i in range(5):
                    print("*",end=" ")
                print()
            else:
                print("   ",end=" ")
                print("*")
                
    def U(self):
        for i in range(0,5):
            if i ==4:
                for j in range(0,5):
                    print("*",end=" ")
            else:
                for k in range(0,5):
                    if k==0 or k==4:
                        print("*",end=" ")
                    else:
                        print(" ",end=" ")
                print()
                
    def V(self):
        for i in range(0,4):
            for j in range(i):
                print(" ",end="")
            print("*",end=" ") 
            for j in range(4-i):
                 print("  ",end="")
            print("*")
        for i in range(5):
            if i == 2:
                print(" *",end=" ")
            else:
                print(" ",end=" ")
    
    def W(self):
        for i in range(0,5): 
            if i==2:
                for j in range(0,5):
                    if j%2==0:
                        print("*",end=' ')
                    else:
                        print(' ',end=' ')
                print()
            elif i==3: 
                for j in range(0,5):
                    if j==2:
                        print(" ",end=' ')
                    else:
                        print('*',end=' ')
                print()
        
            else:            
                for k in range(0,5):
                    if k==0 or k==4:
                        print("*",end=" ")
                    else:
                        print(" ",end=" ")
                print()
        
    
    def X(self):       
        for i in range(0,3):
                for j in range(0,i):
                        print(" ",end=' ')
                if i!=2:
                        print('*',end=' ')
                for j in range(0,3-(i+1)):
                        print(" ",end=' ')
                        print(" ",end=' ')
                if i==2:
                       print(' *')
                else:
                       print("*")

        for i in range(0,2):
                for j in range(0,2-(i+1)):
                     print(" ",end=' ')
                print('*',end=' ')
                for j in range(0,i+1):
                    print(" ",end=' ')
                    print(" ",end=' ')
                print("*")
        
        
    def Y(self):
        print("*",end=" ")
        for j in range(3):
            print(" ",end=" ")
        print("*")
        for i in range(5):
            if i%2!=0:
                print("*",end=" ")
            else:
                print(" ",end=" ")
        for j in range(3):
            print()
            for i in range(5):
                    if i == 2:
                        print("*",end=" ")
                    else:
                        print(" ",end=" ")     
        
    def Z(self):    
         for i in range(0,5):
            if i==0 or i==4:
                for j in range(0,5):
                    print("*",end=' ')
                print()
            else:
                for i in range(0,5-i):
                    print(" ",end=' ')
                print("*")    
        
        
    def msg(self):
        if self.text=='A':
                self.A()
        elif self.text=='B':
                self.B()
        elif self.text=='C':
                self.C()
        elif self.text=='D':
                self.D()
        if self.text=='E':
                self.E()
        elif self.text=='F':
                self.F()
        elif self.text=='G':
                self.G()
        elif self.text=='H':
                self.H()
        if self.text=='I':
                self.I()
        elif self.text=='J':
                self.J()
        elif self.text=='K':
                self.K()
        elif self.text=='L':
                self.L()
        if self.text=='M':
                self.M()
        elif self.text=='N':
                self.N()
        elif self.text=='O':
                self.O()
        elif self.text=='P':
                self.P()
        if self.text=='Q':
                self.Q()
        elif self.text=='R':
                self.R()
        elif self.text=='S':
                self.S()
        elif self.text=='T':
                self.T()
        if self.text=='U':
                self.U()
        elif self.text=='V':
                self.V()
        elif self.text=='W':
                self.W()
        elif self.text=='X':
                self.X()
        elif self.text=='Y':
                self.Y()
        elif self.text=='Z':
                self.Z()

# %%
import string
alp=[]
t=True
T=True
for a in string.ascii_uppercase:
    alp.append(a)
print(" ***  WELCOME  ***")
while(t):
        Alp=input("Enter Any Alphabet")
        if Alp.upper()  in alp:
                P=Pattern(Alp.upper())
                P.msg()
                while(T):
                    C=input("Do You Want Continue Y/N ?").upper()
                    print(C)
                    if C == 'Y':
                        t=True
                        break
                    elif C =='N':
                        print(" ***  THANK YOU  ***")
                        T=False
                        t=False
                    else:
                        print("Enter 'Y' or 'N'")
# Out:
#  ***  WELCOME  ***
# Enter Any Alphabetj
# * * * * *
#       *
#       *
#       *
# * * *
# Do You Want Continue Y/N ?uhbtfy
# UHBTFY
# Enter 'Y' or 'N'

# %%
q
